# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/home/moglix/Downloads/EV_new (2).csv")

# %%
df
# Out:
#         Identifier           City  Postal Code  Model Year        Make  \
# 0       KL8CL6S05E         Tacoma      98407.0        2014   CHEVROLET
# 1       JTDKARFP0H  Port Townsend      98368.0        2017      TOYOTA
# 2       JHMZC5F34J         Vashon      98070.0        2018       HONDA
# 3       KMHC65LD0K     Ridgefield      98642.0        2019     HYUNDAI
# 4       1N4AZ1CP6J      Bremerton      98337.0        2018      NISSAN
# ...            ...            ...          ...         ...         ...
# 135033  JTDKARFP0H   Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L        Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N         Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N     Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L        Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# ...

# %% [markdown]
# ## Bar Charts

# %%
electric_vehicle_counts = df['Electric Vehicle Type'].value_counts()

plt.figure(figsize=(10, 6)) 
electric_vehicle_counts.plot(kind='bar', color='skyblue')
plt.title("Electric Vehicle Type Distribution")
plt.xlabel("Electric Vehicle Type")
plt.ylabel("Count")
plt.xticks(rotation=45) 
plt.tight_layout()

plt.show()

# %%
eligibility_counts = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
plt.figure(figsize=(10, 6)) 
eligibility_counts.plot(kind='bar', color='green')
plt.title("CAFV Eligibility Distribution")
plt.xlabel("Eligibility Status")
plt.ylabel("Count")
plt.xticks(rotation=45) 
plt.tight_layout()
plt.show()

# %%
make_counts = df['Make'].value_counts()
plt.figure(figsize=(12, 6)) 
make_counts.plot(kind='bar', color='purple')
plt.title("Car Make Distribution")
plt.xlabel("Make")
plt.ylabel("Count")
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Histogram

# %%
electric_range = df['Electric Range']
plt.figure(figsize=(10, 6))  
plt.hist(electric_range, bins=20, color='blue', edgecolor='black')
plt.title("Electric Range Histogram")
plt.xlabel("Electric Range")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %%
model_year = df['Model Year']
plt.figure(figsize=(10, 6))  
plt.hist(model_year, bins=20, color='orange', edgecolor='black')
plt.title("Model Year Histogram")
plt.xlabel("Model Year")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatter_plot

# %%
electric_range = df['Electric Range']
base_msrp = df['Base MSRP']

plt.figure(figsize=(10, 6)) 
plt.scatter(electric_range, base_msrp, color='red', alpha=0.5)
plt.title("Electric Range vs. Base MSRP")
plt.xlabel("Electric Range")
plt.ylabel("Base MSRP")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
model_year = df['Model Year']
base_msrp = df['Base MSRP']

plt.figure(figsize=(10, 6)) 
plt.scatter(model_year, base_msrp, color='green', alpha=0.5)
plt.title("Model Year vs. Base MSRP")
plt.xlabel("Model Year")
plt.ylabel("Base MSRP")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Box Plot

# %%
plt.figure(figsize=(12, 8)) 
df.boxplot(column='Base MSRP', by='Electric Vehicle Type', vert=False)
plt.title("Base MSRP by Electric Vehicle Type")
plt.xlabel("Base MSRP")
plt.ylabel("Electric Vehicle Type")
plt.grid(axis='x', alpha=0.75)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(14, 14))  
plt.xticks(rotation=90)  
plt.boxplot([df[df['Make'] == make]['Electric Range'] for make in df['Make'].unique()], labels = df['Make'].unique())
plt.title("Electric Range by Manufacturer (Make)")
plt.xlabel("Manufacturer (Make)")
plt.ylabel("Electric Range")
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %%
summary_stats = df.describe()
summary_stats
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  135030.000000  135038.000000   135037.000000  135037.000000
# mean    98171.001577    2019.662880       74.591964   81017.615211
# std      2450.367211       3.001676       98.744120   23727.350901
# min      1730.000000    1997.000000        0.000000   26455.735798
# 25%     98052.000000    2018.000000        0.000000   63713.207686
# 50%     98121.000000    2021.000000       21.000000   76983.777737
# 75%     98370.000000    2022.000000      150.000000  114632.706686
# max     99701.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District    Vehicle ID  2020 Census Tract
# count         134726.000000  1.350380e+05       1.350300e+05
# mean              29.504379  2.063432e+08       5.297233e+10
# std               14.783780  8.582417e+07       1.635783e+09
# min                1.000000  4.385000e+03       1.081042e+09
# ...

# %% [markdown]
# ## Analytical Insights

# %% [markdown]
# Postal Code:
# The data includes postal codes ranging from a minimum of 1730 to a maximum of 99701.
# The majority of postal codes are clustered around the mean value of approximately 98171.
#
# Model Year:
# The dataset primarily consists of vehicle model years between 1997 and 2024.
# The most common model years are around 2019, with a mean value of approximately 2019.66.
#
# Electric Range:
# The electric range of vehicles varies widely, with values ranging from 0 to 337 miles.
# The mean electric range is approximately 74.59 miles, with a significant standard deviation of approximately 98.74 miles, indicating substantial variability in this attribute.
#
# Base MSRP:
# The base manufacturer's suggested retail price (MSRP) of vehicles in the dataset ranges from $26,455.74 to $845,000.00.
# The mean base MSRP is approximately $81,017.62, with a standard deviation of approximately $23,727.35.
#
# Legislative District:
# Legislative district values range from 1 to 49.
# The data is spread across different legislative districts, and there is no clear concentration in a specific district.
#
# Vehicle ID:
# Vehicle IDs vary widely, with a minimum value of 4,385 and a maximum value of 479,254,800.
# The distribution of Vehicle IDs is not inherently informative as it depends on the system used for assigning IDs.
#
# 2020 Census Tract:
# Census tract values range from approximately 1.081 billion to 5.603 billion.
# These values do not correspond to traditional census tract numbers but rather serve as unique identifiers.
#
# Battery electric vehicle (BEV) counts are higher than plug-in hybrid vehicle (PHEV) counts in your dataset suggests a higher preference for BEVs compared to PHEVs among the vehicles included in our dataset. This finding is consistent with a broader trend seen in many regions where there is a growing interest in and preference for fully electric vehicles for several reasons.
#
# Observation that Clean Alternative Fuel Vehicle (CAFV) counts are higher in our dataset indicates a relatively higher prevalence of vehicles eligible for CAFV incentives compared to other types of vehicles.
#
# Observation that the majority of electric vehicles in our dataset have an electric range between 0 and 100 miles suggests that a significant portion of these vehicles have relatively lower electric ranges.
#  ****potential explanations for this distribution
#  -Affordability
#  -Urban Use
#  -Charging Infrastructure
#
# Observation that most car models in our dataset are from recent years, specifically 2019 and beyond, is indicative of a trend in the automotive industry known as "model year concentration." This trend is influenced by several factors
#  ****This trend is influenced by several factors
#  -Consumer Demand
#  -Technological Advancements
#  -Environmental Regulations
#  -Incentives and Rebates

# %% [markdown]
# Battery Electric vehicle count are higher than plug in hybrid vehicle , this mean people are prefring BEV more than plug in hybrids

# %% [markdown]
# CAFV counts are higher in the dataset

# %% [markdown]
# 0-100 electric range has the higher no. of count

# %% [markdown]
# most car models are from the recent years
